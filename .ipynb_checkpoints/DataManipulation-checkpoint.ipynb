# %% [markdown]
# # REPRESENTATION

# %% [markdown]
# ### IMPORT DEPENDENCIES

# %%
# =============================================================== #
# IMPORTING DEPENDENCIES
# =============================================================== #
# FOR DATA
# =============================================================== #
import pandas as pd
import os
import csv
import math
import numpy as np
import time
import datetime
import matplotlib.pyplot as plt
import scipy.stats as sts
from scipy.stats import sem
from scipy.stats import linregress
import random
from config import msql_serverName, msql_dbName
# import requests
# import datefinder

# =============================================================== #
# # FOR SQL ALCHEMY
# =============================================================== #
import sqlalchemy
from sqlalchemy import create_engine
from datetime import date

# =============================================================== #
# # FOR JSON
# =============================================================== #
from flask import (
    Flask,
    render_template,
    jsonify,
    request,
    redirect)
import json

# %%
# =============================================================== #
# IMPORTING DATA
# =============================================================== #
path1 = os.path.join('data',f'CountriesPopulation_v1.csv')
path2 = os.path.join('data',f'OECD_Countries.csv')
path3 = os.path.join('data',f'Large_Countries.csv')
path4 = os.path.join('data',f'USStatesCongressionalSeats.csv')
path5 = os.path.join('data',f'USStatesCongressionalSeatsHistory.csv')
path6 = os.path.join('data',f'USStatesPopulation.csv')
path7 = os.path.join('data',f'USStatesPopulationHistoric.csv')

# %%
# =============================================================== #
# CONVERTING TO DATAFRAMES
# =============================================================== #
CountriesPopulation_df = pd.read_csv(path1, encoding = "ISO-8859-1", skipinitialspace=True)
OECD_Countries_df = pd.read_csv(path2, encoding = "ISO-8859-1", skipinitialspace=True)
Large_Countries_df = pd.read_csv(path3, encoding = "ISO-8859-1", skipinitialspace=True)
USStatesCongressionalSeats_df = pd.read_csv(path4, encoding = "ISO-8859-1", skipinitialspace=True)
USStatesCongressionalSeatsHistory_df = pd.read_csv(path5, encoding = "ISO-8859-1", skipinitialspace=True)
USStatesPopulation_df = pd.read_csv(path6, encoding = "ISO-8859-1", skipinitialspace=True)
USStatesPopulationHistoric_df = pd.read_csv(path7, encoding = "ISO-8859-1", skipinitialspace=True)

# %%
CountriesPopulation_df.head()
# Out:
#                    Country  Population countrycode_2 countrycode Independent
# 0              Afghanistan  32890171.0            AF         AFG         Yes
# 1  Aland Islands (Finland)     30152.0            AX         ALA          No
# 2                  Albania   2845955.0            AL         ALB         Yes
# 3                  Algeria  44700000.0            DZ         DZA         Yes
# 4      American Samoa (US)     56951.0            AS         ASM          No

# %%
# =============================================================== #
# SAVE THE CSV
# =============================================================== #
CountriesPopulation_df.to_csv("test1.csv", index = False)

# =============================================================== #
# IMPORTING DATA
# =============================================================== #
testpath1 = os.path.join(f'test1.csv')
testpath_df = pd.read_csv(testpath1, encoding = "ISO-8859-1", skipinitialspace=True)
testpath_df
# Out:
#                             Country   Population countrycode_2 countrycode  \
# 0                     Â Afghanistan   32890171.0            AF         AFG
# 1           Aland Islands (Finland)      30152.0            AX         ALA
# 2                         Â Albania    2845955.0            AL         ALB
# 3                         Â Algeria   44700000.0            DZ         DZA
# 4             Â American Samoa (US)      56951.0            AS         ASM
# ..                              ...          ...           ...         ...
# 233                         Â Yemen   30491000.0            YE         YEM
# 234                        Â Zambia   18400556.0            ZM         ZMB
# 235                      Â Zimbabwe   15790716.0            ZW         ZWE
# 236  British Indian Ocean Territory          NaN            IO         IOT
# 237                  European Union  447706209.0            EU         EUR
#
#     Independent
# 0           Yes
# 1            No
# 2           Yes
# 3           Yes
# 4            No
# ..          ...
# 233         Yes
# 234         Yes
# 235         Yes
# 236          No
# 237          No
#
# [238 rows x 5 columns]

# %% [markdown]
# ### PART 1A REPRESENTATION US VS OECD COUNTRIES

# %%
# =============================================================== #
# Combine the data into a single dataset
# =============================================================== #
OECDCountriesPopCongressionalSeats_df = pd.merge(CountriesPopulation_df, OECD_Countries_df, how='left', on='countrycode')

# =============================================================== #
# Getting rid of columns we don't need
# =============================================================== #
OECDCountriesPopCongressionalSeats_df = OECDCountriesPopCongressionalSeats_df[['Country', 'countrycode', 'Population', 'federal representatives', 'upper house']]

# =============================================================== #
# Renaming columns
# =============================================================== #
OECDCountriesPopCongressionalSeats_df = OECDCountriesPopCongressionalSeats_df.rename(columns={'federal representatives': 'LHR', 'upper house': 'UHR', 'countrycode': 'countryCode'})

# =============================================================== #
# Remove any blanks, reset
# =============================================================== #
OECDCountriesPopCongressionalSeats_df = OECDCountriesPopCongressionalSeats_df.dropna(how='any')
OECDCountriesPopCongressionalSeats_df.reset_index()
OECDCountriesPopCongressionalSeats_df
# print(CountriesPopulationCongressionalSeats_df.dtypes)

# =============================================================== #
# Convert object to numeric
# =============================================================== #
OECDCountriesPopCongressionalSeats_df['Population'] = OECDCountriesPopCongressionalSeats_df['Population'].apply(pd.to_numeric, errors='coerce')

# =============================================================== #
# Round numbers
# =============================================================== #
OECDCountriesPopCongressionalSeats_df['Population'] = round(OECDCountriesPopCongressionalSeats_df['Population'], 0)
OECDCountriesPopCongressionalSeats_df['LHR'] = round(OECDCountriesPopCongressionalSeats_df['LHR'], 0)
OECDCountriesPopCongressionalSeats_df['UHR'] = round(OECDCountriesPopCongressionalSeats_df['UHR'], 0)

print(OECDCountriesPopCongressionalSeats_df.dtypes)
OECDCountriesPopCongressionalSeats_df.head()
# Out:
# Country         object
# countryCode     object
# Population     float64
# LHR            float64
# UHR            float64
# dtype: object
#        Country countryCode  Population    LHR    UHR
# 12   Australia         AUS  25776464.0  151.0   76.0
# 13     Austria         AUT   8933346.0  183.0   61.0
# 20     Belgium         BEL  11556297.0  150.0   60.0
# 36      Canada         CAN  38411882.0  338.0  105.0
# 41       Chile         CHL  19678363.0  155.0   43.0

# %%
# =============================================================== #
# Calculate LHCPR (Lower House Citizens per Representative) and UHCPR (Upper House Citizens per Representative)
# =============================================================== #
for index, row in OECDCountriesPopCongressionalSeats_df.iterrows():
    OECDCountriesPopCongressionalSeats_df.loc[index,"CPRLH"] = row["Population"] / row["LHR"]
    if OECDCountriesPopCongressionalSeats_df.loc[index,"UHR"] > 0:
        OECDCountriesPopCongressionalSeats_df.loc[index,"CPRUH"] = row["Population"] / row["UHR"]
    else:
        OECDCountriesPopCongressionalSeats_df.loc[index,"CPRUH"] = 0
    
# =============================================================== #
# Round numbers
# =============================================================== #
OECDCountriesPopCongressionalSeats_df['Population'] = round(OECDCountriesPopCongressionalSeats_df['Population'], 0)
OECDCountriesPopCongressionalSeats_df['CPRLH'] = round(OECDCountriesPopCongressionalSeats_df['CPRLH'], 0)
OECDCountriesPopCongressionalSeats_df['CPRUH'] = round(OECDCountriesPopCongressionalSeats_df['CPRUH'], 0)

# =============================================================== #
# Add in Group column
# =============================================================== #
OECDCountriesPopCongressionalSeats_df['Groups'] = "OECD Countries"

OECDCountriesPopCongressionalSeats_df.head(50)
# Out:
#              Country countryCode   Population    LHR    UHR     CPRLH  \
# 12         Australia         AUS   25776464.0  151.0   76.0  170705.0
# 13           Austria         AUT    8933346.0  183.0   61.0   48816.0
# 20           Belgium         BEL   11556297.0  150.0   60.0   77042.0
# 36            Canada         CAN   38411882.0  338.0  105.0  113645.0
# 41             Chile         CHL   19678363.0  155.0   43.0  126957.0
# 54    Czech Republic         CZE   10701777.0  200.0   81.0   53509.0
# 55           Denmark         DNK    5840045.0  179.0    0.0   32626.0
# 66           Estonia         EST    1329460.0  101.0    0.0   13163.0
# 72           Finland         FIN    5508198.0  200.0    0.0   27541.0
# 73            France         FRA   67399000.0  577.0  348.0  116809.0
# 78           Germany         DEU   83190556.0  709.0   69.0  117335.0
# 81            Greece         GRC   10718565.0  300.0    0.0   35729.0
# 93           Hungary         HUN    9730000.0  199.0    0.0   48894.0
# 94           Iceland         ISL     368590.0   63.0    0.0    5851.0
# 99           Ireland         IRL    4977400.0  160.0   60.0   31109.0
# 101           Israel         ISR    9334340.0  120.0    0.0   77786.0
# 102            Italy         ITA   59257566.0  630.0  321.0   94060.0
# 105            Japan         JPN  125480000.0  465.0  245.0  269849.0
# 114           Latvia         LVA    1891300.0  100.0    0.0   18913.0
# 120        Lithuania         LTU    2790044.0  141.0    0.0   19788.0
# 121       Luxembourg         LUX     634730.0   60.0    0.0   10579.0
# 132           Mexico         MEX  126014024.0  500.0  128.0  252028.0
# 144      Netherlands         NLD   17580531.0  150.0   75.0  117204.0
# 146      New Zealand         NZL    5123792.0  120.0    0.0   42698.0
# 155           Norway         NOR    5391369.0  196.0    0.0   27507.0
# 166           Poland         POL   38244000.0  460.0  100.0   83139.0
# 167         Portugal         PRT   10295909.0  230.0    0.0   44765.0
# 190         Slovakia         SVK    5459781.0  150.0    0.0   36399.0
# 191         Slovenia         SVN    2111461.0   90.0    0.0   23461.0
# 195      South Korea         KOR   51705905.0  300.0    0.0  172353.0
# 198            Spain         ESP   47351567.0  350.0  265.0  135290.0
# 202           Sweden         SWE   10380491.0  349.0    0.0   29744.0
# 203      Switzerland         CHE    8655100.0  200.0   46.0   43276.0
# 214           Turkey         TUR   83614362.0  600.0    0.0  139357.0
# 222   United Kingdom         GBR   66796807.0  650.0  796.0  102764.0
# 223    United States         USA  331458869.0  435.0  100.0  761974.0
# 237   European Union         EUR  447706209.0  705.0    0.0  635044.0
#
#          CPRUH          Groups
# 12    339164.0  OECD Countries
# 13    146448.0  OECD Countries
# 20    192605.0  OECD Countries
# 36    365827.0  OECD Countries
# 41    457636.0  OECD Countries
# 54    132121.0  OECD Countries
# 55         0.0  OECD Countries
# 66         0.0  OECD Countries
# 72         0.0  OECD Countries
# 73    193675.0  OECD Countries
# 78   1205660.0  OECD Countries
# 81         0.0  OECD Countries
# 93         0.0  OECD Countries
# 94         0.0  OECD Countries
# 99     82957.0  OECD Countries
# 101        0.0  OECD Countries
# 102   184603.0  OECD Countries
# 105   512163.0  OECD Countries
# 114        0.0  OECD Countries
# 120        0.0  OECD Countries
# 121        0.0  OECD Countries
# 132   984485.0  OECD Countries
# 144   234407.0  OECD Countries
# 146        0.0  OECD Countries
# 155        0.0  OECD Countries
# 166   382440.0  OECD Countries
# 167        0.0  OECD Countries
# 190        0.0  OECD Countries
# 191        0.0  OECD Countries
# 195        0.0  OECD Countries
# 198   178685.0  OECD Countries
# 202        0.0  OECD Countries
# 203   188154.0  OECD Countries
# 214        0.0  OECD Countries
# 222    83916.0  OECD Countries
# 223  3314589.0  OECD Countries
# 237        0.0  OECD Countries

# %%
# =============================================================== #
# GENERATE BAR PLOT FOR LOWER HOUSE
# =============================================================== #
# Getting rid of columns we don't need
# =============================================================== #
CountryvsSeats_LowerHouse_df = OECDCountriesPopCongressionalSeats_df[['Country', 'CPRLH']]

# =============================================================== #
# Sort data
# =============================================================== #
CountryvsSeats_LowerHouse_df = CountryvsSeats_LowerHouse_df.sort_values(by='CPRLH')

# =============================================================== #
# Create x-axis
# =============================================================== #
Country_List = CountryvsSeats_LowerHouse_df['Country'].unique()
CountryNo = np.array(range(len(Country_List)))

# =============================================================== #
# Create Plot Method 1 (pandasplot)
# =============================================================== #
CountryvsSeats_LowerHouse_df.plot(kind="bar", figsize=(10,5))
plt.title("Number of citizens per representative (Lower House) for OECD Countries")
plt.xticks(CountryNo, Country_List,rotation = 90)
plt.tight_layout()
plt.show()

# %%
# =============================================================== #
# GENERATE BAR PLOT FOR UPPER HOUSE
# =============================================================== #
# Getting rid of columns we don't need
# =============================================================== #
UpperHouse_df = OECDCountriesPopCongressionalSeats_df[OECDCountriesPopCongressionalSeats_df['UHR']>0] 
CountryvsSeats_UpperHouse_df = UpperHouse_df[['Country', 'CPRUH']]

# =============================================================== #
# Sort data
# =============================================================== #
CountryvsSeats_UpperHouse_df = CountryvsSeats_UpperHouse_df.sort_values(by='CPRUH')

# =============================================================== #
# Create x-axis
# =============================================================== #
Country_List = CountryvsSeats_UpperHouse_df['Country'].unique()
CountryNo = np.array(range(len(Country_List)))

# =============================================================== #
# Create Plot Method 1 (pandasplot)
# =============================================================== #
CountryvsSeats_UpperHouse_df.plot(kind="bar", figsize=(10,5))
plt.title("Number of citizens per representative (Upper House) for OECD Countries")
plt.xticks(CountryNo, Country_List,rotation = 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### PART 1B: REPRESENTATION US VS RANDOM COUNTRIES

# %%
# =============================================================== #
# Combine the data into a single dataset
# =============================================================== #
CountriesPopulationCongressionalSeats_df = pd.merge(CountriesPopulation_df, Large_Countries_df, how='left', on='countrycode')

# =============================================================== #
# Getting rid of columns we don't need
# =============================================================== #
CountriesPopulationCongressionalSeats_df = CountriesPopulationCongressionalSeats_df[['Country', 'countrycode', 'Population_x', 'Federal Representatives', 'Upper house']]

# =============================================================== #
# Renaming columns
# =============================================================== #
CountriesPopulationCongressionalSeats_df = CountriesPopulationCongressionalSeats_df.rename(columns={'Population_x': 'Population', 'Federal Representatives': 'LHR', 'Upper house': 'UHR', 'countrycode': 'countryCode'})

# =============================================================== #
# Remove any blanks, reset
# =============================================================== #
CountriesPopulationCongressionalSeats_df = CountriesPopulationCongressionalSeats_df.dropna(how='any')
CountriesPopulationCongressionalSeats_df.reset_index()
CountriesPopulationCongressionalSeats_df
# print(CountriesPopulationCongressionalSeats_df.dtypes)

# =============================================================== #
# Convert object to numeric
# =============================================================== #
CountriesPopulationCongressionalSeats_df['Population'] = CountriesPopulationCongressionalSeats_df['Population'].apply(pd.to_numeric, errors='coerce')

# =============================================================== #
# Round numbers
# =============================================================== #
CountriesPopulationCongressionalSeats_df['Population'] = round(CountriesPopulationCongressionalSeats_df['Population'], 0)
CountriesPopulationCongressionalSeats_df['LHR'] = round(CountriesPopulationCongressionalSeats_df['LHR'], 0)
CountriesPopulationCongressionalSeats_df['UHR'] = round(CountriesPopulationCongressionalSeats_df['UHR'], 0)

print(CountriesPopulationCongressionalSeats_df.dtypes)
CountriesPopulationCongressionalSeats_df.head()
# Out:
# Country         object
# countryCode     object
# Population     float64
# LHR            float64
# UHR            float64
# dtype: object
#                  Country countryCode  Population    LHR    UHR
# 3                Algeria         DZA  44700000.0  462.0  144.0
# 8    Antigua and Barbuda         ATG     99337.0   17.0   17.0
# 9              Argentina         ARG  45808747.0  257.0   72.0
# 15               Bahamas         BHS    393450.0   39.0   16.0
# 16               Bahrain         BHR   1501635.0   40.0   40.0

# %%
# =============================================================== #
# Calculate LHCPR (Lower House Citizens per Representative) and UHCPR (Upper House Citizens per Representative)
# =============================================================== #
for index, row in CountriesPopulationCongressionalSeats_df.iterrows():
    CountriesPopulationCongressionalSeats_df.loc[index,"CPRLH"] = row["Population"] / row["LHR"]
    if CountriesPopulationCongressionalSeats_df.loc[index,"UHR"] > 0:
        CountriesPopulationCongressionalSeats_df.loc[index,"CPRUH"] = row["Population"] / row["UHR"]
    else:
        CountriesPopulationCongressionalSeats_df.loc[index,"CPRUH"] = 0

# =============================================================== #
# Round numbers
# =============================================================== #
CountriesPopulationCongressionalSeats_df['Population'] = round(CountriesPopulationCongressionalSeats_df['Population'], 0)
CountriesPopulationCongressionalSeats_df['CPRLH'] = round(CountriesPopulationCongressionalSeats_df['CPRLH'], 0)
CountriesPopulationCongressionalSeats_df['CPRUH'] = round(CountriesPopulationCongressionalSeats_df['CPRUH'], 0)

# =============================================================== #
# Add in Group column
# =============================================================== #
CountriesPopulationCongressionalSeats_df['Groups'] = "Random Countries"

CountriesPopulationCongressionalSeats_df.head(50)
# Out:
#                     Country countryCode    Population     LHR    UHR  \
# 16     37541.0    37541.0  Random Countries
# 17    487010.0        0.0  Random Countries
# 28    415145.0  2629253.0  Random Countries
# 30     13924.0        0.0  Random Countries
# 42    472283.0        0.0  Random Countries
# 51     18502.0        0.0  Random Countries
# 59    184756.0   847505.0  Random Countries
# 62    170662.0   339049.0  Random Countries
# 73    116809.0   193675.0  Random Countries
# 78    117335.0  1205660.0  Random Countries
# 83      7533.0     8692.0  Random Countries
# 92    106774.0        0.0  Random Countries
# 95   2533025.0  5614012.0  Random Countries
# 96    471913.0  1995221.0  Random Countries
# 97    290829.0        0.0  Random Countries
# 102    94060.0   184603.0  Random Countries
# 105   269849.0   512163.0  Random Countries
# 109   136287.0   709915.0  Random Countries
# 110     2683.0        0.0  Random Countries
# 114    18913.0        0.0  Random Countries
# 116    16727.0    60824.0  Random Countries
# 119     1562.0        0.0  Random Countries
# 122    20700.0        0.0  Random Countries
# 128     7680.0        0.0  Random Countries
# 132   252028.0   984485.0  Random Countries
# 134     1588.0        0.0  Random Countries
# 149   587225.0  1939459.0  Random Countries
# 157   658480.0  2252000.0  Random Countries
# 164   362033.0  4585753.0  Random Countries
# 171   324974.0   860225.0  Random Countries
# 175     3600.0        0.0  Random Countries
# 181      560.0        0.0  Random Countries
# 183   228121.0        0.0  Random Countries
# 186     2828.0        0.0  Random Countries
# 188    54671.0        0.0  Random Countries
# 207   148605.0   660467.0  Random Countries
# 212     2733.0     5467.0  Random Countries
# 213   285570.0   377689.0  Random Countries
# 214   385320.0        0.0  Random Countries
# 220    69258.0        0.0  Random Countries
# 222   148437.0        0.0  Random Countries
# 223   761974.0  3314589.0  Random Countries
# 229   202029.0        0.0  Random Countries

# %%
# =============================================================== #
# GENERATE BAR PLOT FOR LOWER HOUSE
# =============================================================== #
# Getting rid of columns we don't need
# =============================================================== #
CountryvsSeats_LowerHouse_df = CountriesPopulationCongressionalSeats_df[['Country', 'CPRLH']]

# =============================================================== #
# Sort data
# =============================================================== #
CountryvsSeats_LowerHouse_df = CountryvsSeats_LowerHouse_df.sort_values(by='CPRLH')

# =============================================================== #
# Create x-axis
# =============================================================== #
Country_List = CountryvsSeats_LowerHouse_df['Country'].unique()
CountryNo = np.array(range(len(Country_List)))

# =============================================================== #
# Create Plot Method 1 (pandasplot)
# =============================================================== #
CountryvsSeats_LowerHouse_df.plot(kind="bar", figsize=(10,5))
plt.title("Number of citizens per representative (Lower House) for Random Countries")
plt.xticks(CountryNo, Country_List,rotation = 90)
plt.tight_layout()
plt.show()

# %%
# =============================================================== #
# GENERATE BAR PLOT FOR UPPER HOUSE
# =============================================================== #
# Getting rid of columns we don't need
# =============================================================== #
UpperHouse_df = CountriesPopulationCongressionalSeats_df[CountriesPopulationCongressionalSeats_df['UHR']>0] 
CountryvsSeats_UpperHouse_df = UpperHouse_df[['Country', 'CPRUH']]

# =============================================================== #
# Sort data
# =============================================================== #
CountryvsSeats_UpperHouse_df = CountryvsSeats_UpperHouse_df.sort_values(by='CPRUH')

# =============================================================== #
# Create x-axis
# =============================================================== #
Country_List = CountryvsSeats_UpperHouse_df['Country'].unique()
CountryNo = np.array(range(len(Country_List)))

# =============================================================== #
# Create Plot Method 1 (pandasplot)
# =============================================================== #
CountryvsSeats_UpperHouse_df.plot(kind="bar", figsize=(10,5))
plt.title("Number of citizens per representative (Upper House) for Random Countries")
plt.xticks(CountryNo, Country_List,rotation = 90)
plt.tight_layout()
plt.show()

# %%
#### MERGE, REMOVE UNWANTED COUNTRIES AND OUTPUT CSV FOR PART1

# %%
# =============================================================== #
### MERGE, REMOVE UNWANTED COUNTRIES AND OUTPUT CSV FOR PART1
# =============================================================== #
# CONCATENATE THE CSVs
# =============================================================== #
Part1_df= pd.concat([OECDCountriesPopCongressionalSeats_df, CountriesPopulationCongressionalSeats_df])

# =============================================================== #
# DELETE UNWANTED ROWS (COUNTRIES)
# =============================================================== #
countriesToDelete = ['CHN', 'EUR', 'IND' ]

n = 0
for country in countriesToDelete:
    deleteRows = Part1_df[Part1_df['countryCode'] == countriesToDelete[n] ].index
    Part1_df.drop(deleteRows, inplace=True)
    n = n + 1

# # =============================================================== #
# # DELETE ANY UNWANTED SPACES (IF ANY)
# # =============================================================== #    
# Part1_df = Part1_df.str.replace(" ", "")
# Part1_df

# =============================================================== #
# SAVE THE CSV
# =============================================================== #
Part1_df.to_csv("data/Part1.csv", index = False)
Part1_df.to_csv("03_metalRoute/Part1.csv", index = False)
Part1_df
# Out:
#              Country countryCode   Population    LHR    UHR     CPRLH  \
# 12         Australia         AUS   25776464.0  151.0   76.0  170705.0
# 13           Austria         AUT    8933346.0  183.0   61.0   48816.0
# 20           Belgium         BEL   11556297.0  150.0   60.0   77042.0
# 36            Canada         CAN   38411882.0  338.0  105.0  113645.0
# 41             Chile         CHL   19678363.0  155.0   43.0  126957.0
# ..               ...         ...          ...    ...    ...       ...
# 214           Turkey         TUR   83614362.0  217.0    0.0  385320.0
# 220          Ukraine         UKR   41554836.0  600.0    0.0   69258.0
# 222   United Kingdom         GBR   66796807.0  450.0    0.0  148437.0
# 223    United States         USA  331458869.0  435.0  100.0  761974.0
# 229          Vietnam         VNM   97580000.0  483.0    0.0  202029.0
#
#          CPRUH            Groups
# 12    339164.0    OECD Countries
# 13    146448.0    OECD Countries
# 20    192605.0    OECD Countries
# 36    365827.0    OECD Countries
# 41    457636.0    OECD Countries
# ..         ...               ...
# 214        0.0  Random Countries
# 220        0.0  Random Countries
# 222        0.0  Random Countries
# 223  3314589.0  Random Countries
# 229        0.0  Random Countries
#
# [81 rows x 8 columns]

# %%
# =============================================================== #
# # # FLASK APP TESTING FOR PART 1
# =============================================================== #
# Make a copy
repData = Part1_df
# Inputs that'll come from user
countries = 'OECD'
house = 'Lower House'

##### Code to get the Dataset needed for graph #####
##### If statement for Country group selection #####
if countries == 'OECD':
    countryGroup1 = 'OECD Countries'
    countryGroup2 = 'OECD Countries'
elif countries == 'RANDOM':
    countryGroup1 = 'Random Countries'
    countryGroup2 = 'Random Countries'
else:
    countryGroup1 = 'OECD Countries'
    countryGroup2 = 'Random Countries'
    
##### If statement for House selection #####
if house == 'Upper House':
    colofInterest1 = 'CPRUH'
    colofInterest2 = 'UHR'
else:
    colofInterest1 = 'CPRLH'
    colofInterest2 = 'LHR'

##### Sort dataframe by countries & house & select columns to keep #####
barGraphData=repData[(repData["Groups"] == countryGroup1) | (repData["Groups"] == countryGroup2)]

##### Filter for data that isn't 0 #####
barGraphData=barGraphData[barGraphData[colofInterest1] != 0]

##### Sort data by Column of Interest #####
sortedBarGraphData = barGraphData.sort_values(by=colofInterest1)

##### Select columns you want for output #####
sortedBarGraphData=sortedBarGraphData[["Country", "countryCode", "Population", colofInterest1, colofInterest2]]

##### Renaming columns #####
Part1b_df = sortedBarGraphData.rename(columns={'Country': 'country', 'countryCode': 'countryCode', 'Population': 'population', colofInterest1: 'cpr', colofInterest2: 'reps'})


# =============================================================== #
# SAVE CSV TO TEST FOLDER
# =============================================================== #
Part1b_df.to_csv("01_barchartRoute/Part1c.csv", index = False)
Part1b_df
# Out:
#              country countryCode   population       cpr   reps
# 94           Iceland         ISL     368590.0    5851.0   63.0
# 121       Luxembourg         LUX     634730.0   10579.0   60.0
# 66           Estonia         EST    1329460.0   13163.0  101.0
# 114           Latvia         LVA    1891300.0   18913.0  100.0
# 120        Lithuania         LTU    2790044.0   19788.0  141.0
# 191         Slovenia         SVN    2111461.0   23461.0   90.0
# 155           Norway         NOR    5391369.0   27507.0  196.0
# 72           Finland         FIN    5508198.0   27541.0  200.0
# 202           Sweden         SWE   10380491.0   29744.0  349.0
# 99           Ireland         IRL    4977400.0   31109.0  160.0
# 55           Denmark         DNK    5840045.0   32626.0  179.0
# 81            Greece         GRC   10718565.0   35729.0  300.0
# 190         Slovakia         SVK    5459781.0   36399.0  150.0
# 146      New Zealand         NZL    5123792.0   42698.0  120.0
# 203      Switzerland         CHE    8655100.0   43276.0  200.0
# 167         Portugal         PRT   10295909.0   44765.0  230.0
# 13           Austria         AUT    8933346.0   48816.0  183.0
# 93           Hungary         HUN    9730000.0   48894.0  199.0
# 54    Czech Republic         CZE   10701777.0   53509.0  200.0
# 20           Belgium         BEL   11556297.0   77042.0  150.0
# 101           Israel         ISR    9334340.0   77786.0  120.0
# 166           Poland         POL   38244000.0   83139.0  460.0
# 102            Italy         ITA   59257566.0   94060.0  630.0
# 222   United Kingdom         GBR   66796807.0  102764.0  650.0
# 36            Canada         CAN   38411882.0  113645.0  338.0
# 73            France         FRA   67399000.0  116809.0  577.0
# 144      Netherlands         NLD   17580531.0  117204.0  150.0
# 78           Germany         DEU   83190556.0  117335.0  709.0
# 41             Chile         CHL   19678363.0  126957.0  155.0
# 198            Spain         ESP   47351567.0  135290.0  350.0
# 214           Turkey         TUR   83614362.0  139357.0  600.0
# 12         Australia         AUS   25776464.0  170705.0  151.0
# 195      South Korea         KOR   51705905.0  172353.0  300.0
# 132           Mexico         MEX  126014024.0  252028.0  500.0
# 105            Japan         JPN  125480000.0  269849.0  465.0
# 223    United States         USA  331458869.0  761974.0  435.0

# %%
# =============================================================== #
# # UPLOAD DATASET TO DATABASE (SQL SERVER DB)
# =============================================================== #
# =============================================================== #
# IMPORTING DEPENDENCIES
# =============================================================== #
from sqlalchemy import create_engine
import urllib

# =============================================================== #
# Set up variables
# =============================================================== #
msql_serverName = 'WORKHORSE_PC\SQLEXPRESS'
msql_dbName = 'representation_v1'

# =============================================================== #
# Set up connection string
# =============================================================== #
conn_str = (
    r'Driver=ODBC Driver 17 for SQL Server;'
    rf'Server={msql_serverName};'
    rf'Database={msql_dbName};'
    r'Trusted_Connection=yes;'
)
quoted_conn_str = urllib.parse.quote_plus(conn_str)
engine = create_engine(f'mssql+pyodbc:///?odbc_connect={quoted_conn_str}')

# =============================================================== #
# Connect to DB and delete (or create) a table
# =============================================================== #
q = """DROP TABLE RepresentationTable3"""
cnxn.execute(q)   

q = """ 
CREATE TABLE RepresentationTable3 (
    Country Varchar (128) NOT NULL,
    countryCode Varchar (128) NOT NULL,
    Population Integer   NOT NULL,
	LHR Integer   NOT NULL,
	UHR Integer   NOT NULL,
	CPRLH Integer   NOT NULL,
	CPRUH Integer   NOT NULL,
    Groups Varchar (128) NOT NULL
)
"""
cnxn.execute(q)  

# =============================================================== #
# Connect to DB and upload df to table
# =============================================================== #
cnxn = engine.connect()
Part1_df.to_sql(name = 'RepresentationTable3', con = cnxn, if_exists = 'append',index = False)
cnxn.close()

# %%
# =============================================================== #
# # UPLOAD DATASET TO DATABASE (POSTGRESS SQL DB)
# =============================================================== #
# You first have to go create the db and then use the same name as the db you have created
# =============================================================== #

# =============================================================== #
# 1 Generate connection string for Local Instance of a Postgres Database
# =============================================================== #
# connection_string1 = f'{pg_user}:{password}@localhost:5432/{db_name}'
    
# =============================================================== #
# 2 Generate connection string for AWS Instance of a Postgres Database
# =============================================================== #
# connection_string2 = f'{dbuser}:{dbpassword}@database-1.cvmfiiilpm7y.us-east-1.rds.amazonaws.com:{dbport}/{dbname}'


# =============================================================== #
# 3 Generate connection string for Microsoft SQl Server Database
# =============================================================== #
# connection_string3 = f'{msql_serverName}/{msql_dbName}?trusted_connection=yes'
# connection_string3 = f'{msql_serverName}/{msql_dbName}?Trusted_Connection=yes?driver=ODBC+Driver+13+for+SQL+Server&authentication=ActiveDirectoryIntegrated'

# engine = sqlalchemy.create_engine('mssql://WORKHORSE_PC\SQLEXPRESS/representation_v1?trusted_connection=yes')
# sqlcon = create_engine('mssql+pyodbc://@' + servername + '/' + dbname + '?trusted_connection=yes&driver=ODBC+Driver+13+for+SQL+Server')
# sqlcon = create_engine('mssql+pyodbc://@' + servername + '/' + dbname + '?trusted_connection=yes&driver=ODBC+Driver+13+for+SQL+Server')

# password = getpass.getpass()
# connection_string3 = f'{msql_serverName}\{username}:{password}@{hostip}/{db}'
# engine = create_engine(eng_str)

# engine = create_engine(
#     "mssql+pyodbc://scott:tiger@myhost:port/databasename"
#     "?driver=ODBC+Driver+17+for+SQL+Server"
#     "&authentication=ActiveDirectoryIntegrated"
# )

# from sqlalchemy.engine import URI
# connection_string = "DRIVER={SQL Server Native Client 10.0};SERVER=WORKHORSE_PC\SQLEXPRESS;DATABASE=representation_v1?Trusted_Connection=yes?"
# connection_url = URI.create("mssql+pyodbc", query={"odbc_connect": connection_string})

# engine = create_engine(connection_url)


# import pyodbc

# pyodbc.pooling = False

# # don't use the engine before pooling is set to False
# engine = create_engine(f"mssql+pyodbc://{connection_string3}")

# from sqlalchemy import create_engine

# connection_string3 = f"{msql_serverName}/{msql_dbName}?Trusted_Connection=yes?driver=ODBC+Driver+17+for+SQL+Server"

# cnxn = engine.connect()


# =============================================================== #
# 4 Connect to database
# =============================================================== #
# engine = create_engine(f'postgresql://{connection_string2}')
# engine = create_engine(f'mssql+pyodbc://{connection_string3}')

# connection = engine.connect()

# =============================================================== #
# 5 Upload Table to db
# =============================================================== #
# Part1_df.to_sql(name='RepresentationTable1', con=engine, if_exists='append',index=False)
# connection.close()

# ================================================================================ #
# 6 Looking for appropriate connection string to connect to Microsoft SQl Server
# =============================================================================== #
# # pyodbc
# engine = create_engine('mssql+pyodbc://scott:tiger@mydsn')

# # pymssql
# engine = create_engine('mssql+pymssql://scott:tiger@hostname:port/dbname')

# %%
# from config import msql_serverName, msql_dbName
# from sqlalchemy import create_engine
# from sqlalchemy.connectors import pyodbc
# from sqlalchemy.engine.url import make_url

# pyodbc.pooling = False

# 1st attempt connection_string = f'{msql_serverName}/{msql_dbName}?trusted_connection=yes'

#2nd attempt connection_string = f'{msql_serverName}/{msql_dbName}?Trusted_Connection=yes?driver=ODBC+Driver+17+for+SQL+Server'

#3rd attempt 
# connection_string = f'{msql_serverName}/{msql_dbName}?Trusted_Connection=yes?driver=ODBC+Driver+17+for+SQL+Server&authentication=ActiveDirectoryIntegrated'

# # Attempt #1 =============================================================================================== # #
# from sqlalchemy import create_engine
# import urllib

# server = 'WORKHORSE_PC\SQLEXPRESS'
# database = 'representation_v1'

# conn_str = (
#     r'Driver=ODBC Driver 17 for SQL Server;'
#     rf'Server={server};'
#     rf'Database={database};'
#     r'Trusted_Connection=yes;'
# )
# quoted_conn_str = urllib.parse.quote_plus(conn_str)
# engine = create_engine(f'mssql+pyodbc:///?odbc_connect={quoted_conn_str}')

# cnxn = engine.connect()

# # # Attempt #1b =========================================================================================== # #
# Part1_df.to_sql(name = 'RepresentationTable1', con = cnxn, if_exists = 'append',index = False)
# cnxn.close()
# # Attempt #1 End ========================================================================================== # #

# # Attempt #1b =========================================================================================== # #
# # Part1_df.to_sql(name = 'RepresentationTable1', con = cnxn, index=False, schema='representation_v1', if_exists = 'replace')
# Part1_df.to_sql(name = 'RepresentationTable1', con = cnxn, index=False, schema='representation_v1', if_exists = 'replace')
# cnxn.close()

# # Attempt #2 =========================================================================================== # #
# engine = create_engine("mssql+pyodbc://" + user + ":" + passwd + "@" +dsnname)
# Part1_df.to_sql(name= 'TableTest', con = engine, if_exists='replace')

# engine = create_engine("teradata://" + user + ":" + passwd + "@" +dsnname)
# Part1_df.to_sql(name= 'RepresentationTable1', con = engine, index=False, schema='representation_v1', if_exists='replace')

# # Attempt #3 =========================================================================================== # #
# # upload data into temp table
# Part1_df.to_sql('RepresentationTable1', cnxn, if_exists='append', index=False)
# cnxn.close()

# # Attempt #3 =========================================================================================== # #
# engine = create_engine("mssql+pyodbc:///?odbc_connect={}".format(params))



# # q = """DROP TABLE RepresentationTable2"""
# # cnxn.execute(q)   

# q = """ 
# CREATE TABLE representation_v1.[RepresentationTable1] (
# 	[Country] VARCHAR(max) NULL, 
# 	[countryCode] VARCHAR(max) NULL, 
# 	[Population] FLOAT(53) NULL, 
# 	[LHR] FLOAT(53) NULL, 
# 	[UHR] FLOAT(53) NULL, 
# 	[CPRLH] FLOAT(53) NULL, 
# 	[CPRUH] FLOAT(53) NULL, 
# 	[Groups] VARCHAR(max) NULL
# )
# """

# q = """ 
# CREATE TABLE RepresentationTable2 (
#     Country Varchar   NOT NULL,
#     countryCode Varchar   NOT NULL,
#     Population Integer   NOT NULL,
# 	LHR Integer   NOT NULL,
# 	UHR Integer   NOT NULL,
# 	CPRLH Integer   NOT NULL,
# 	CPRUH Integer   NOT NULL,
#     Groups Varchar   NOT NULL,
# )
# """
# cnxn.execute(q)    

# # upload data into temp table
# Part1_df.to_sql('RepresentationTable1', cnxn, if_exists='append', index=False)
# cnxn.close()
# # Attempt #3 =========================================================================================== # #
# # rows = cnxn.execute("SELECT name FROM sys.tables").fetchall()
# # print(rows)

# # engine = create_engine(f'mssql+pyodbc://{connection_string}')
# engine = create_engine('mssql+pyodbc://my_sqlserver_ds1')
# engine = create_engine(f'mssql+pyodbc://{server}/{database}')

# connMaster = pyodbc.connect('DRIVER={SQL Server Native Client 10.0}; 
# SERVER=.\DT_SQLEXPR2008;DATABASE=master;Trusted_Connection=yes;')
# cursorMaster = connMaster.cursor()

# # connection = engine.connect()

# Part1_df.to_sql(name='RepresentationTable1', con=engine, if_exists='append',index=False)

# # connection.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\pyodbc.py in do_executemany(self, cursor, statement, parameters, context)
#     346         super(MSDialect_pyodbc, self).do_executemany(
# --> 347             cursor, statement, parameters, context=context
#     348         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     576     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 577         cursor.executemany(statement, parameters)
#     578
#
# ProgrammingError: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]String or binary data would be truncated in table 'representation_v1.dbo.RepresentationTable1', column 'Country'. Truncated value: '\xa0'. (2628) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The statement has been terminated. (3621)")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-103-19bfbe1337c0> in <module>
#      32
#      33 # # Attempt #1b =========================================================================================== # #
# ---> 34 Part1_df.to_sql(name = 'RepresentationTable1', con = cnxn, if_exists = 'append',index = False)
#      35 cnxn.close()
#      36
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1318         )
#    1319         table.create()
# -> 1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#    1322             # check for potentially case sensitivity issues (GH7815)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     754
#     755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 756                 exec_insert(conn, keys, chunk_iter)
#     757
#     758     def _query_iterator(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         """
#     669         data = [dict(zip(keys, row)) for row in data_iter]
# --> 670         conn.execute(self.table.insert(), data)
#     671
#     672     def _execute_insert_multi(self, conn, keys, data_iter):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                 if not evt_handled:
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#    1231             elif not parameters and context.no_parameters:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\pyodbc.py in do_executemany(self, cursor, statement, parameters, context)
#     345             cursor.fast_executemany = True
#     346         super(MSDialect_pyodbc, self).do_executemany(
# --> 347             cursor, statement, parameters, context=context
#     348         )
#     349
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     575
#     576     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 577         cursor.executemany(statement, parameters)
#     578
#     579     def do_execute(self, cursor, statement, parameters, context=None):
#
# ProgrammingError: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]String or binary data would be truncated in table 'representation_v1.dbo.RepresentationTable1', column 'Country'. Truncated value: '\xa0'. (2628) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]The statement has been terminated. (3621)")
# [SQL: INSERT INTO [RepresentationTable1] ([Country], [countryCode], [Population], [LHR], [UHR], [CPRLH], [CPRUH], [Groups]) VALUES (?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: (('\xa0Australia', 'AUS', 25776464.0, 151.0, 76.0, 170705.0, 339164.0, 'OECD Countries'), ('\xa0Austria', 'AUT', 8933346.0, 183.0, 61.0, 48816.0, 146448.0, 'OECD Countries'), ('\xa0Belgium', 'BEL', 11556297.0, 150.0, 60.0, 77042.0, 192605.0, 'OECD Countries'), ('\xa0Canada', 'CAN', 38411882.0, 338.0, 105.0, 113645.0, 365827.0, 'OECD Countries'), ('\xa0Chile', 'CHL', 19678363.0, 155.0, 43.0, 126957.0, 457636.0, 'OECD Countries'), ('\xa0Czech Republic', 'CZE', 10701777.0, 200.0, 81.0, 53509.0, 132121.0, 'OECD Countries'), ('\xa0Denmark', 'DNK', 5840045.0, 179.0, 0.0, 32626.0, 0.0, 'OECD Countries'), ('\xa0Estonia', 'EST', 1329460.0, 101.0, 0.0, 13163.0, 0.0, 'OECD Countries')  ... displaying 10 of 81 total bound parameter sets ...  ('\xa0United States', 'USA', 331458869.0, 435.0, 100.0, 761974.0, 3314589.0, 'Random Countries'), ('\xa0Vietnam', 'VNM', 97580000.0, 483.0, 0.0, 202029.0, 0.0, 'Random Countries'))]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# from sqlalchemy.connectors import pyodbc
# from sqlalchemy.engine.url import make_url


# #3rd attempt 
# connection_string = f'{msql_serverName}/{msql_dbName}?Trusted_Connection=yes?driver=ODBC+Driver+17+for+SQL+Server&authentication=ActiveDirectoryIntegrated'


# conn = pyodbc.PyODBCConnector()
# url = make_url(f'mssql+pyodbc://{connection_string}')
# url = make_url('mssql+pyodbc://DSN=py_test; Trusted_Connection=Yes')
# connect_args = conn.create_connect_args(url)
# print(connect_args)

# This returns:

# [['dsn=DSN=py_test; Trusted_Connection=Yes;Trusted_Connection=Yes'], {}]

# where you can see there's an extra "DSN=" in there.  

# There's a large number of connection examples for Pyodbc here:  http://docs.sqlalchemy.org/en/rel_0_8/dialects/mssql.html#additional-connection-examples

# You can see, that for standard "TrustedConnection", you only need the dsn name:

# create_engine('mssql+pyodbc://mydsn')

# which our test script shows the arguments as:

# [['dsn=mydsn;Trusted_Connection=Yes'], {}]

# looks good to me, so good luck !
# Out:
# [["dsn='DSN=py_test; Trusted_Connection=Yes';Trusted_Connection=Yes"], {}]

# %%
# =============================================================== #
# CREATE JSON
# =============================================================== #
from ast import literal_eval

data = literal_eval(Part1_df.to_json(orient='records'))
data

# =============================================================== #
# SAVE THE JSON
# =============================================================== #
data.to_json("test1json.json", index = False)
# # Make a json of all the Part1 data
# ##### Convert data to a dictionary #####
# Part1_dt = Part1_df.to_dict()

# # ##### Jsonify the data #####
# Part1_json = Part1_dt.to_json()
# Part1_json

# # Make a copy
# repData = Part1_df
# # Inputs that'll come from user
# countries = 'OECD'
# house = 'Lower House'

# ##### Code to get the Dataset needed for graph #####
#     ##### If statement for Country group selection #####
#     if countries == 'OECD':
#         countryGroup1 = 'OECD Countries'
#         countryGroup2 = 'OECD Countries'
#     elif countries == 'RANDOM':
#         countryGroup1 = 'Random Countries'
#         countryGroup2 = 'Random Countries'
#     else:
#         countryGroup1 = 'OECD Countries'
#         countryGroup2 = 'Random Countries'

#     ##### If statement for House selection #####
#     if house == 'Upper House':
#         colofInterest1 = 'CPRUH'
#         colofInterest2 = 'UHR'
#     else:
#         colofInterest1 = 'CPRLH'
#         colofInterest2 = 'LHR'

#     ##### Sort dataframe by countries & house & select columns to keep #####
#     barGraphData = repData[(repData["Group"] == countryGroup1)
#                            | (repData["Group"] == countryGroup2)]

#     ##### Filter for data that isn't 0 #####
#     barGraphData = barGraphData[barGraphData[colofInterest1] != 0]

#     ##### Sort data by Column of Interest #####
#     sortedBarGraphData = barGraphData.sort_values(by=colofInterest1)

#     ##### Select columns you want for output #####
#     sortedBarGraphData = sortedBarGraphData[[
#         "Country", "countryCode", "Population", colofInterest1, colofInterest2]]

#     ##### Renaming columns #####
#     sortedBarGraphData = sortedBarGraphData.rename(
#         columns={'Country': 'country', 'countryCode': 'countryCode', 'Population': 'population', colofInterest1: 'cpr', colofInterest2: 'reps'})

#     ##### Convert data to a dictionary #####
#     sortedBarGraphData = sortedBarGraphData.to_dict()

#     ##### Jsonify the data #####
#     return jsonify(sortedBarGraphData)

# ######################### ROUTE FOR ALL DATA ############################
# @app.route("/allData")
# def allData():
#     allData = repData

#     allData = allData.to_dict()

#     return jsonify(allData)
# Out:
# [{'Country': '\xa0Australia',
#   'countryCode': 'AUS',
#   'Population': 25776464.0,
#   'LHR': 151.0,
#   'UHR': 76.0,
#   'CPRLH': 170705.0,
#   'CPRUH': 339164.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Austria',
#   'countryCode': 'AUT',
#   'Population': 8933346.0,
#   'LHR': 183.0,
#   'UHR': 61.0,
#   'CPRLH': 48816.0,
#   'CPRUH': 146448.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Belgium',
#   'countryCode': 'BEL',
#   'Population': 11556297.0,
#   'LHR': 150.0,
#   'UHR': 60.0,
#   'CPRLH': 77042.0,
#   'CPRUH': 192605.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Canada',
#   'countryCode': 'CAN',
#   'Population': 38411882.0,
#   'LHR': 338.0,
#   'UHR': 105.0,
#   'CPRLH': 113645.0,
#   'CPRUH': 365827.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Chile',
#   'countryCode': 'CHL',
#   'Population': 19678363.0,
#   'LHR': 155.0,
#   'UHR': 43.0,
#   'CPRLH': 126957.0,
#   'CPRUH': 457636.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Czech Republic',
#   'countryCode': 'CZE',
#   'Population': 10701777.0,
#   'LHR': 200.0,
#   'UHR': 81.0,
#   'CPRLH': 53509.0,
#   'CPRUH': 132121.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Denmark',
#   'countryCode': 'DNK',
#   'Population': 5840045.0,
#   'LHR': 179.0,
#   'UHR': 0.0,
#   'CPRLH': 32626.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Estonia',
#   'countryCode': 'EST',
#   'Population': 1329460.0,
#   'LHR': 101.0,
#   'UHR': 0.0,
#   'CPRLH': 13163.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Finland',
#   'countryCode': 'FIN',
#   'Population': 5508198.0,
#   'LHR': 200.0,
#   'UHR': 0.0,
#   'CPRLH': 27541.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0France',
#   'countryCode': 'FRA',
#   'Population': 67399000.0,
#   'LHR': 577.0,
#   'UHR': 348.0,
#   'CPRLH': 116809.0,
#   'CPRUH': 193675.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Germany',
#   'countryCode': 'DEU',
#   'Population': 83190556.0,
#   'LHR': 709.0,
#   'UHR': 69.0,
#   'CPRLH': 117335.0,
#   'CPRUH': 1205660.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Greece',
#   'countryCode': 'GRC',
#   'Population': 10718565.0,
#   'LHR': 300.0,
#   'UHR': 0.0,
#   'CPRLH': 35729.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Hungary',
#   'countryCode': 'HUN',
#   'Population': 9730000.0,
#   'LHR': 199.0,
#   'UHR': 0.0,
#   'CPRLH': 48894.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Iceland',
#   'countryCode': 'ISL',
#   'Population': 368590.0,
#   'LHR': 63.0,
#   'UHR': 0.0,
#   'CPRLH': 5851.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Ireland',
#   'countryCode': 'IRL',
#   'Population': 4977400.0,
#   'LHR': 160.0,
#   'UHR': 60.0,
#   'CPRLH': 31109.0,
#   'CPRUH': 82957.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Israel',
#   'countryCode': 'ISR',
#   'Population': 9334340.0,
#   'LHR': 120.0,
#   'UHR': 0.0,
#   'CPRLH': 77786.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Italy',
#   'countryCode': 'ITA',
#   'Population': 59257566.0,
#   'LHR': 630.0,
#   'UHR': 321.0,
#   'CPRLH': 94060.0,
#   'CPRUH': 184603.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Japan',
#   'countryCode': 'JPN',
#   'Population': 125480000.0,
#   'LHR': 465.0,
#   'UHR': 245.0,
#   'CPRLH': 269849.0,
#   'CPRUH': 512163.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Latvia',
#   'countryCode': 'LVA',
#   'Population': 1891300.0,
#   'LHR': 100.0,
#   'UHR': 0.0,
#   'CPRLH': 18913.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Lithuania',
#   'countryCode': 'LTU',
#   'Population': 2790044.0,
#   'LHR': 141.0,
#   'UHR': 0.0,
#   'CPRLH': 19788.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Luxembourg',
#   'countryCode': 'LUX',
#   'Population': 634730.0,
#   'LHR': 60.0,
#   'UHR': 0.0,
#   'CPRLH': 10579.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Mexico',
#   'countryCode': 'MEX',
#   'Population': 126014024.0,
#   'LHR': 500.0,
#   'UHR': 128.0,
#   'CPRLH': 252028.0,
#   'CPRUH': 984485.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Netherlands',
#   'countryCode': 'NLD',
#   'Population': 17580531.0,
#   'LHR': 150.0,
#   'UHR': 75.0,
#   'CPRLH': 117204.0,
#   'CPRUH': 234407.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0New Zealand',
#   'countryCode': 'NZL',
#   'Population': 5123792.0,
#   'LHR': 120.0,
#   'UHR': 0.0,
#   'CPRLH': 42698.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Norway',
#   'countryCode': 'NOR',
#   'Population': 5391369.0,
#   'LHR': 196.0,
#   'UHR': 0.0,
#   'CPRLH': 27507.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Poland',
#   'countryCode': 'POL',
#   'Population': 38244000.0,
#   'LHR': 460.0,
#   'UHR': 100.0,
#   'CPRLH': 83139.0,
#   'CPRUH': 382440.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Portugal',
#   'countryCode': 'PRT',
#   'Population': 10295909.0,
#   'LHR': 230.0,
#   'UHR': 0.0,
#   'CPRLH': 44765.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Slovakia',
#   'countryCode': 'SVK',
#   'Population': 5459781.0,
#   'LHR': 150.0,
#   'UHR': 0.0,
#   'CPRLH': 36399.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Slovenia',
#   'countryCode': 'SVN',
#   'Population': 2111461.0,
#   'LHR': 90.0,
#   'UHR': 0.0,
#   'CPRLH': 23461.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0South Korea',
#   'countryCode': 'KOR',
#   'Population': 51705905.0,
#   'LHR': 300.0,
#   'UHR': 0.0,
#   'CPRLH': 172353.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Spain',
#   'countryCode': 'ESP',
#   'Population': 47351567.0,
#   'LHR': 350.0,
#   'UHR': 265.0,
#   'CPRLH': 135290.0,
#   'CPRUH': 178685.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Sweden',
#   'countryCode': 'SWE',
#   'Population': 10380491.0,
#   'LHR': 349.0,
#   'UHR': 0.0,
#   'CPRLH': 29744.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Switzerland',
#   'countryCode': 'CHE',
#   'Population': 8655100.0,
#   'LHR': 200.0,
#   'UHR': 46.0,
#   'CPRLH': 43276.0,
#   'CPRUH': 188154.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Turkey',
#   'countryCode': 'TUR',
#   'Population': 83614362.0,
#   'LHR': 600.0,
#   'UHR': 0.0,
#   'CPRLH': 139357.0,
#   'CPRUH': 0.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0United Kingdom',
#   'countryCode': 'GBR',
#   'Population': 66796807.0,
#   'LHR': 650.0,
#   'UHR': 796.0,
#   'CPRLH': 102764.0,
#   'CPRUH': 83916.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0United States',
#   'countryCode': 'USA',
#   'Population': 331458869.0,
#   'LHR': 435.0,
#   'UHR': 100.0,
#   'CPRLH': 761974.0,
#   'CPRUH': 3314589.0,
#   'Groups': 'OECD Countries'},
#  {'Country': '\xa0Algeria',
#   'countryCode': 'DZA',
#   'Population': 44700000.0,
#   'LHR': 462.0,
#   'UHR': 144.0,
#   'CPRLH': 96753.0,
#   'CPRUH': 310417.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Antigua and Barbuda',
#   'countryCode': 'ATG',
#   'Population': 99337.0,
#   'LHR': 17.0,
#   'UHR': 17.0,
#   'CPRLH': 5843.0,
#   'CPRUH': 5843.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Argentina',
#   'countryCode': 'ARG',
#   'Population': 45808747.0,
#   'LHR': 257.0,
#   'UHR': 72.0,
#   'CPRLH': 178244.0,
#   'CPRUH': 636233.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Bahamas',
#   'countryCode': 'BHS',
#   'Population': 393450.0,
#   'LHR': 39.0,
#   'UHR': 16.0,
#   'CPRLH': 10088.0,
#   'CPRUH': 24591.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Bahrain',
#   'countryCode': 'BHR',
#   'Population': 1501635.0,
#   'LHR': 40.0,
#   'UHR': 40.0,
#   'CPRLH': 37541.0,
#   'CPRUH': 37541.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Bangladesh',
#   'countryCode': 'BGD',
#   'Population': 170453540.0,
#   'LHR': 350.0,
#   'UHR': 0.0,
#   'CPRLH': 487010.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Brazil',
#   'countryCode': 'BRA',
#   'Population': 212969523.0,
#   'LHR': 513.0,
#   'UHR': 81.0,
#   'CPRLH': 415145.0,
#   'CPRUH': 2629253.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Brunei',
#   'countryCode': 'BRN',
#   'Population': 459500.0,
#   'LHR': 33.0,
#   'UHR': 0.0,
#   'CPRLH': 13924.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Cuba',
#   'countryCode': 'CUB',
#   'Population': 11193470.0,
#   'LHR': 605.0,
#   'UHR': 0.0,
#   'CPRLH': 18502.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0DR Congo',
#   'countryCode': 'COD',
#   'Population': 92378000.0,
#   'LHR': 500.0,
#   'UHR': 109.0,
#   'CPRLH': 184756.0,
#   'CPRUH': 847505.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Egypt',
#   'countryCode': 'EGY',
#   'Population': 101714695.0,
#   'LHR': 596.0,
#   'UHR': 300.0,
#   'CPRLH': 170662.0,
#   'CPRUH': 339049.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0France',
#   'countryCode': 'FRA',
#   'Population': 67399000.0,
#   'LHR': 577.0,
#   'UHR': 348.0,
#   'CPRLH': 116809.0,
#   'CPRUH': 193675.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Germany',
#   'countryCode': 'DEU',
#   'Population': 83190556.0,
#   'LHR': 709.0,
#   'UHR': 69.0,
#   'CPRLH': 117335.0,
#   'CPRUH': 1205660.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Grenada',
#   'countryCode': 'GRD',
#   'Population': 113000.0,
#   'LHR': 15.0,
#   'UHR': 13.0,
#   'CPRLH': 7533.0,
#   'CPRUH': 8692.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Hong Kong',
#   'countryCode': 'HKG',
#   'Population': 7474200.0,
#   'LHR': 70.0,
#   'UHR': 0.0,
#   'CPRLH': 106774.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Indonesia',
#   'countryCode': 'IDN',
#   'Population': 271350000.0,
#   'LHR': 575.0,
#   'UHR': 136.0,
#   'CPRLH': 471913.0,
#   'CPRUH': 1995221.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Iran',
#   'countryCode': 'IRN',
#   'Population': 84340498.0,
#   'LHR': 290.0,
#   'UHR': 0.0,
#   'CPRLH': 290829.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Italy',
#   'countryCode': 'ITA',
#   'Population': 59257566.0,
#   'LHR': 630.0,
#   'UHR': 321.0,
#   'CPRLH': 94060.0,
#   'CPRUH': 184603.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Japan',
#   'countryCode': 'JPN',
#   'Population': 125480000.0,
#   'LHR': 465.0,
#   'UHR': 245.0,
#   'CPRLH': 269849.0,
#   'CPRUH': 512163.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Kenya',
#   'countryCode': 'KEN',
#   'Population': 47564296.0,
#   'LHR': 349.0,
#   'UHR': 67.0,
#   'CPRLH': 136287.0,
#   'CPRUH': 709915.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Kiribati',
#   'countryCode': 'KIR',
#   'Population': 120740.0,
#   'LHR': 45.0,
#   'UHR': 0.0,
#   'CPRLH': 2683.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Latvia',
#   'countryCode': 'LVA',
#   'Population': 1891300.0,
#   'LHR': 100.0,
#   'UHR': 0.0,
#   'CPRLH': 18913.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Lesotho',
#   'countryCode': 'LSO',
#   'Population': 2007201.0,
#   'LHR': 120.0,
#   'UHR': 33.0,
#   'CPRLH': 16727.0,
#   'CPRUH': 60824.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Liechtenstein',
#   'countryCode': 'LIE',
#   'Population': 39062.0,
#   'LHR': 25.0,
#   'UHR': 0.0,
#   'CPRLH': 1562.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Macau',
#   'countryCode': 'MAC',
#   'Population': 683100.0,
#   'LHR': 33.0,
#   'UHR': 0.0,
#   'CPRLH': 20700.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Malta',
#   'countryCode': 'MLT',
#   'Population': 514564.0,
#   'LHR': 67.0,
#   'UHR': 0.0,
#   'CPRLH': 7680.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Mexico',
#   'countryCode': 'MEX',
#   'Population': 126014024.0,
#   'LHR': 500.0,
#   'UHR': 128.0,
#   'CPRLH': 252028.0,
#   'CPRUH': 984485.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Monaco',
#   'countryCode': 'MCO',
#   'Population': 38100.0,
#   'LHR': 24.0,
#   'UHR': 0.0,
#   'CPRLH': 1588.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Nigeria',
#   'countryCode': 'NGA',
#   'Population': 211401000.0,
#   'LHR': 360.0,
#   'UHR': 109.0,
#   'CPRLH': 587225.0,
#   'CPRUH': 1939459.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Pakistan',
#   'countryCode': 'PAK',
#   'Population': 225200000.0,
#   'LHR': 342.0,
#   'UHR': 100.0,
#   'CPRLH': 658480.0,
#   'CPRUH': 2252000.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Philippines',
#   'countryCode': 'PHL',
#   'Population': 110058083.0,
#   'LHR': 304.0,
#   'UHR': 24.0,
#   'CPRLH': 362033.0,
#   'CPRUH': 4585753.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Russia',
#   'countryCode': 'RUS',
#   'Population': 146238185.0,
#   'LHR': 450.0,
#   'UHR': 170.0,
#   'CPRLH': 324974.0,
#   'CPRUH': 860225.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Saint Kitts and Nevis',
#   'countryCode': 'KNA',
#   'Population': 54000.0,
#   'LHR': 15.0,
#   'UHR': 0.0,
#   'CPRLH': 3600.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0San Marino',
#   'countryCode': 'SMR',
#   'Population': 33600.0,
#   'LHR': 60.0,
#   'UHR': 0.0,
#   'CPRLH': 560.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Saudi Arabia',
#   'countryCode': 'SAU',
#   'Population': 34218169.0,
#   'LHR': 150.0,
#   'UHR': 0.0,
#   'CPRLH': 228121.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Seychelles',
#   'countryCode': 'SYC',
#   'Population': 98963.0,
#   'LHR': 35.0,
#   'UHR': 0.0,
#   'CPRLH': 2828.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Singapore',
#   'countryCode': 'SGP',
#   'Population': 5685807.0,
#   'LHR': 104.0,
#   'UHR': 0.0,
#   'CPRLH': 54671.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Tanzania',
#   'countryCode': 'TZA',
#   'Population': 59441988.0,
#   'LHR': 400.0,
#   'UHR': 90.0,
#   'CPRLH': 148605.0,
#   'CPRUH': 660467.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Trinidad and Tobago',
#   'countryCode': 'TTO',
#   'Population': 1366725.0,
#   'LHR': 500.0,
#   'UHR': 250.0,
#   'CPRLH': 2733.0,
#   'CPRUH': 5467.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Tunisia',
#   'countryCode': 'TUN',
#   'Population': 11708370.0,
#   'LHR': 41.0,
#   'UHR': 31.0,
#   'CPRLH': 285570.0,
#   'CPRUH': 377689.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Turkey',
#   'countryCode': 'TUR',
#   'Population': 83614362.0,
#   'LHR': 217.0,
#   'UHR': 0.0,
#   'CPRLH': 385320.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Ukraine',
#   'countryCode': 'UKR',
#   'Population': 41554836.0,
#   'LHR': 600.0,
#   'UHR': 0.0,
#   'CPRLH': 69258.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0United Kingdom',
#   'countryCode': 'GBR',
#   'Population': 66796807.0,
#   'LHR': 450.0,
#   'UHR': 0.0,
#   'CPRLH': 148437.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0United States',
#   'countryCode': 'USA',
#   'Population': 331458869.0,
#   'LHR': 435.0,
#   'UHR': 100.0,
#   'CPRLH': 761974.0,
#   'CPRUH': 3314589.0,
#   'Groups': 'Random Countries'},
#  {'Country': '\xa0Vietnam',
#   'countryCode': 'VNM',
#   'Population': 97580000.0,
#   'LHR': 483.0,
#   'UHR': 0.0,
#   'CPRLH': 202029.0,
#   'CPRUH': 0.0,
#   'Groups': 'Random Countries'}]

# %% [markdown]
# ### PART 2: US POPULATION HISTORY AND CONGRESSIONAL SEATS

# %%
USStatesPopulationHistoric_df
# Out:
#                          State Abbr  Year Admitted 1790_TotalPopulation  \
# 0                      Alabama   AL         1819.0                  NaN
# 1                       Alaska   AK         1959.0                  NaN
# 2                      Arizona   AZ         1912.0                  NaN
# 3                     Arkansas   AR         1836.0                  NaN
# 4                   California   CA         1850.0                  NaN
# 5                     Colorado   CO         1876.0                  NaN
# 6                  Connecticut   CT         1788.0              237,946
# 7                     Delaware   DE         1787.0               59,096
# 8         District of Columbia   DC         1790.0                  NaN
# 9                      Florida   FL         1845.0                  NaN
# 10                     Georgia   GA         1788.0               82,548
# 11                      Hawaii   HI         1959.0                  NaN
# 19              151,719              228,705              298,335
# 20              341,548              380,546              407,350
# 21              422,845              472,040              523,287
# 22                3,757                4,762                7,452
# 23                    0                    0                    0
# 24                7,600               31,306               75,448
# 25                    0               19,783               66,586
# 26                    0                    0                    0
# 27                    0                    0                    0
# 28                    0                    0                    0
# 29              183,858              214,360              244,161
# 30              211,149              245,555              277,575
# 31                    0                    0                    0
# 32              586,050              959,049            1,372,812
# 33              478,103              556,526              638,829
# 34                    0                    0                    0
# 35               42,159              230,760              581,434
# 36                    0                    0                    0
# 37                    0                    0                    0
# 38              602,545              810,091            1,049,458
# 39                    0                    0                    0
# 40               69,122               76,931               83,059
# 41              345,591              415,115              502,741
# 42                    0                    0                    0
# 43              105,602              261,727              422,813
# 44                    0                    0                    0
# 45                    0                    0                    0
# 46              154,465              217,713              235,764
# 47              807,557              877,683              938,261
# 48                    0                    0                    0
# 49               78,592              105,469              136,808
# 50                    0                    0                1,444
# 51                    0                    0                    0
# 52                    0                    0                    0
# 53                    0                    0                    0
# 54                    0                    0                    0
# 55                    0                    0                    0
# 56                    0                    0                    0
# 57                    0                    0                    0
# 58                    0                    0                    0
#
#    1830_TotalPopulation 1840_TotalPopulation 1850_TotalPopulation  ...  \
# 0               309,527              590,756              771,623  ...
# 1                     0                    0                    0  ...
# 2                     0                    0                    0  ...
# 3                30,388               97,574              209,897  ...
# 4                     0                    0               92,597  ...
# 5                     0                    0                    0  ...
# 6               297,675              309,978              370,792  ...
# 7                76,748               78,085               91,532  ...
# 8                30,261               33,745               51,687  ...
# 9                34,730               54,477               87,445  ...
# 10              516,823              691,392              906,185  ...
# 11                    0                    0                    0  ...
# 12                    0                    0                    0  ...
# 13              157,445              476,183              851,470  ...
# 14              343,031              685,866              988,416  ...
# 15                    0               43,112              192,214  ...
# 16                    0                    0                    0  ...
# 17              687,917              779,828              982,405  ...
# 18              215,739              352,411              517,762  ...
# 19              399,455              501,793              583,169  ...
# 20              447,040              470,019              583,034  ...
# 21              610,408              737,699              994,514  ...
# 22               28,004              212,267              397,654  ...
# 23                    0                    0                6,077  ...
# 24              136,621              375,651              606,526  ...
# 25              140,455              383,702              682,044  ...
# 26                    0                    0                    0  ...
# 27                    0                    0                    0  ...
# 28                    0                    0                    0  ...
# 29              269,328              284,574              317,976  ...
# 30              320,823              373,306              489,555  ...
# 31                    0                    0               61,547  ...
# 32            1,918,608            2,428,921            3,097,394  ...
# 33              737,987              753,419              869,039  ...
# 34                    0                    0                    0  ...
# 35              937,903            1,519,467            1,980,329  ...
# 36                    0                    0                    0  ...
# 37                    0                    0               12,093  ...
# 38            1,348,233            1,724,033            2,311,786  ...
# 39                    0                    0                    0  ...
# 40               97,199              108,830              147,545  ...
# 41              581,185              594,398              668,507  ...
# 42                    0                    0                    0  ...
# 43              681,904              829,210            1,002,717  ...
# 44                    0                    0              212,592  ...
# 45                    0                    0               11,380  ...
# 46              280,652              291,948              314,120  ...
# 47            1,044,054            1,025,227            1,119,348  ...
# 48                    0                    0                1,201  ...
# 49              176,924              224,537              302,313  ...
# 50                3,635               30,945              305,391  ...
# 51                    0                    0                    0  ...
# 52                    0                    0                    0  ...
# 53                    0                    0                    0  ...
# 54                    0                    0                    0  ...
# 55                    0                    0                    0  ...
# 56                    0                    0                    0  ...
# 57                    0                    0                    0  ...
# 58                    0                    0                    0  ...
#
#    1950_TotalPopulation 1960_TotalPopulation 1970_TotalPopulation  \
# 0             3,061,743            3,266,740            3,444,165
# 1               128,643              226,167              300,382
# 2               749,587            1,302,161            1,770,900
# 3             1,909,511            1,786,272            1,923,295
# 4            10,586,223           15,717,204           19,953,134
# 5             1,325,089            1,753,947            2,207,259
# 6             2,007,280            2,535,234            3,031,709
# 7               318,085              446,292              548,104
# 8               802,178              763,956              756,510
# 9             2,771,305            4,951,560            6,789,443
# 10            3,444,578            3,943,116            4,589,575
# 11              499,794              632,772              768,561
# 12              588,637              667,191              712,567
# 13            8,712,176           10,081,158           11,113,976
# 14            3,934,224            4,662,498            5,193,669
# 15            2,621,073            2,757,537            2,824,376
# 16            1,905,299            2,178,611            2,246,578
# 17            2,944,806            3,038,156            3,218,706
# 18            2,683,516            3,257,022            3,641,306
# 19              913,774              969,265              992,048
# 20            2,343,001            3,100,689            3,922,399
# 21            4,690,514            5,148,578            5,689,170
# 22            6,371,766            7,823,194            8,875,083
# 23            2,982,483            3,413,864            3,804,971
# 24            2,178,914            2,178,141            2,216,912
# 25            3,954,653            4,319,813            4,676,501
# 26              591,024              674,767              694,409
# 27            1,325,510            1,411,330            1,483,493
# 28              160,083              285,278              488,738
# 29              533,242              606,921              737,681
# 30            4,835,329            6,066,782            7,168,164
# 31              681,187              951,023            1,016,000
# 32           14,830,192           16,782,304           18,236,967
# 33            4,061,929            4,556,155            5,082,059
# 34              619,636              632,446              617,761
# 35            7,946,627            9,706,397           10,652,017
# 36            2,233,351            2,328,284            2,559,229
# 37            1,521,341            1,768,687            2,091,385
# 38           10,498,012           11,319,366           11,793,909
# 39            2,210,703            2,349,544            2,712,033
# 40              791,896              859,488              946,725
# 41            2,117,027            2,382,594            2,590,516
# 42              652,740              680,514              665,507
# 43            3,291,718            3,567,089            3,923,687
# 44            7,711,194            9,579,677           11,196,730
# 45              688,862              890,627            1,059,273
# 46              377,747              389,881              444,330
# 47            3,318,680            3,966,949            4,648,494
# 48            2,378,963            2,853,214            3,409,169
# 49            2,005,552            1,860,421            1,744,237
# 50            3,434,575            3,951,777            4,417,731
# 51              290,529              330,066              332,416
# 52               24,889               20,051               27,159
# 53               59,498               67,044               84,966
# 54                    0                    0                9,460
# 55                    0                    0               70,270
# 56                    0                    0               11,210
# 57               52,822               42,112               44,198
# 58               51,827               32,099               62,468
#
#    1980_TotalPopulation 1990_TotalPopulation 2000_TotalPopulation  \
# 0             3,893,888            4,040,587            4,447,100
# 1               401,851              550,043              626,932
# 2             2,718,215            3,665,228            5,130,632
# 3             2,286,435            2,350,725            2,673,400
# 4            23,667,902           29,760,021           33,871,648
# 5             2,889,964            3,294,394            4,301,261
# 15            3,046,355         3,167,970.00            3190369.0     56.7157
# 16            2,853,118         2,917,220.00            2937880.0     35.6807
# 17            4,339,367         4,480,710.00            4505836.0    113.4759
# 18            4,533,372         4,627,000.00            4657757.0    107.0966
# 19            1,328,361         1,354,520.00            1362359.0     43.9166
# 20            5,773,552         6,065,440.00            6177224.0    624.8522
# 21            6,547,629         6,912,240.00            7029917.0    886.1846
# 22            9,883,640         9,992,430.00           10077331.0    176.7352
# 23            5,303,925         5,706,400.00            5706494.0     71.6641
# 24            2,967,297         2,966,410.00            2961279.0     63.2187
# 25            5,988,927         6,169,040.00            6154913.0     89.7419
# 26              989,415         1,085,000.00            1084225.0      7.4547
# 27            1,826,341         1,952,000.00            1961504.0     25.4087
# 28            2,700,551         3,185,790.00            3104614.0     29.0195
# 29            1,316,470         1,372,200.00            1377529.0    153.2671
# 30            8,791,894         8,874,520.00            9288994.0   1206.7609
# 31            2,059,179         2,105,000.00            2117522.0     17.3540
# 32           19,378,102        19,300,000.00           20201249.0    409.5404
# 33            9,535,483        10,701,000.00           10439388.0    220.1037
# 34              672,591           770,026.00             779094.0     11.1596
# 35           11,536,504        11,714,600.00           11799448.0    286.6939
# 36            3,751,351         3,990,440.00            3959353.0     58.1739
# 37            3,831,074         4,289,440.00            4237256.0     44.6873
# 38           12,702,379        12,804,100.00           13002700.0    286.1699
# 39            3,725,789         3,194,370.00            3285874.0    923.4952
# 40            1,052,567         1,061,510.00            1097379.0   1026.6054
# 41            4,625,364         5,277,830.00            5118425.0    175.5707
# 42              814,180           896,581.00             886667.0     11.8265
# 43            6,346,105         6,944,260.00            6910840.0    168.4069
# 44           25,145,561        29,730,300.00           29145505.0    113.8080
# 45            2,763,885         3,310,770.00            3271616.0     40.2917
# 46              625,741           623,251.00             643077.0     67.6197
# 47            8,001,024         8,603,980.00            8631393.0    217.8774
# 48            6,724,540         7,796,940.00            7705281.0    117.3248
# 49            1,852,994         1,767,860.00            1793716.0     73.5444
# 50            5,686,986         5,852,490.00            5893718.0    108.0633
# 51              563,626           581,075.00             576851.0      5.9847
# 52               55,519                    0                  0.0      0.0000
# 53              159,358                    0                  0.0      0.0000
# 54               53,883                    0                  0.0      0.0000
# 55                    0                    0                  0.0      0.0000
# 56                    0                    0                  0.0      0.0000
# 57                    0                    0                  0.0      0.0000
# 58              106,405                    0                  0.0      0.0000
#
# [59 rows x 37 columns]

# %%
# for index, row in USStatesPopulationHistoric_df.iterrows():
#     USStatesPopulationHistoric_df.loc[index,"1790_RepPopulation"] = row["1790_TotalPopulation"] +(0.60 * (row["1790_EnslavedPopulation"]))
# #     if CountriesPopulationCongressionalSeats_df.loc[index,"upper house"] != NaN:
# #         CountriesPopulationCongressionalSeats_df.loc[index,"upper_house per head"] = row["Population"] / row["upper house"]
# USStatesPopulationHistoric_df

# spare_df = USStatesPopulationHistoric_df
# USStatesPopulationHistoric_df = spare_df
USStatesPopulationHistoric_df

# Remove NaN values
# USStatesPopulationHistoric_df.fillna(0)
New_USStatesPopulationHistoric_df = USStatesPopulationHistoric_df.replace(np.nan,0)
###################################################################################################################################################################
# Convert object to numeric
# weather["Temp"] = pd.to_numeric(weather.Temp, errors='coerce')
# New_USStatesPopulationHistoric_df["1790_TotalPopulation"] = pd.to_numeric(New_USStatesPopulationHistoric_df["1790_TotalPopulation"], errors='coerce')
# New_USStatesPopulationHistoric_df = New_USStatesPopulationHistoric_df.apply(pd.to_numeric, errors='coerce')
# New_USStatesPopulationHistoric_df['State'] = New_USStatesPopulationHistoric_df['State'].astype(str)
# New_USStatesPopulationHistoric_df['Abbr'] = New_USStatesPopulationHistoric_df['Abbr'].astype(str)

# # USStatesPopulationHistoric_df = USStatesPopulationHistoric_df.dropna(how='any')
# New_USStatesPopulationHistoric_df["1790_RepPopulation"] = New_USStatesPopulationHistoric_df["1790_TotalPopulation"] +(0.60 * (New_USStatesPopulationHistoric_df["1790_EnslavedPopulation"]))
# New_USStatesPopulationHistoric_df["1800_RepPopulation"] = New_USStatesPopulationHistoric_df["1800_TotalPopulation"] +(0.60 * (New_USStatesPopulationHistoric_df["1800_EnslavedPopulation"]))
# New_USStatesPopulationHistoric_df["1810_RepPopulation"] = New_USStatesPopulationHistoric_df["1810_TotalPopulation"] +(0.60 * (New_USStatesPopulationHistoric_df["1810_EnslavedPopulation"]))
# New_USStatesPopulationHistoric_df["1820_RepPopulation"] = New_USStatesPopulationHistoric_df["1820_TotalPopulation"] +(0.60 * (New_USStatesPopulationHistoric_df["1820_EnslavedPopulation"]))
# New_USStatesPopulationHistoric_df["1830_RepPopulation"] = New_USStatesPopulationHistoric_df["1830_TotalPopulation"] +(0.60 * (New_USStatesPopulationHistoric_df["1830_EnslavedPopulation"]))
# New_USStatesPopulationHistoric_df["1840_RepPopulation"] = New_USStatesPopulationHistoric_df["1840_TotalPopulation"] +(0.60 * (New_USStatesPopulationHistoric_df["1840_EnslavedPopulation"]))
# New_USStatesPopulationHistoric_df["1850_RepPopulation"] = New_USStatesPopulationHistoric_df["1850_TotalPopulation"] +(0.60 * (New_USStatesPopulationHistoric_df["1850_EnslavedPopulation"]))
# New_USStatesPopulationHistoric_df["1860_RepPopulation"] = New_USStatesPopulationHistoric_df["1860_TotalPopulation"] +(0.60 * (New_USStatesPopulationHistoric_df["1860_EnslavedPopulation"]))
print(New_USStatesPopulationHistoric_df.dtypes)
New_USStatesPopulationHistoric_df
# Out:
# State                       object
# Abbr                        object
# Year Admitted              float64
# 1790_TotalPopulation        object
# 1800_TotalPopulation        object
# 1810_TotalPopulation        object
# 1820_TotalPopulation        object
# 1830_TotalPopulation        object
# 1840_TotalPopulation        object
# 1850_TotalPopulation        object
# 1860_TotalPopulation        object
# 1790_EnslavedPopulation     object
# 1800_EnslavedPopulation     object
# 1810_EnslavedPopulation     object
# 1820_EnslavedPopulation     object
# 1830_EnslavedPopulation     object
# 1840_EnslavedPopulation     object
# 1850_EnslavedPopulation     object
# 1860_EnslavedPopulation     object
# 1870_TotalPopulation        object
# 1880_TotalPopulation        object
# 1                     0                    0                    0
# 2                     0                    0                    0
# 3                     0                1,062               14,273
# 4                     0                    0                    0
# 5                     0                    0                    0
# 6               251,002              262,042              275,202
# 7                64,273               72,674               72,749
# 8                 8,144               15,471               23,336
# 9                     0                    0                    0
# 10              162,686              251,407              340,989
# 11                    0                    0                    0
# 12                    0                    0                    0
# 13                2,458               12,282               55,211
# 14                2,632               24,520              147,178
# 15                    0                    0                    0
# 16                    0                    0                    0
# 17              220,959              406,511              564,317
# 18                    0               76,556              153,407
# 19              151,719              228,705              298,335
# 20              341,548              380,546              407,350
# 21              422,845              472,040              523,287
# 22                3,757                4,762                7,452
# 23                    0                    0                    0
# 24                7,600               31,306               75,448
# 25                    0               19,783               66,586
# 26                    0                    0                    0
# 27                    0                    0                    0
# 28                    0                    0                    0
# 29              183,858              214,360              244,161
# 30              211,149              245,555              277,575
# 31                    0                    0                    0
# 32              586,050              959,049            1,372,812
# 33              478,103              556,526              638,829
# 34                    0                    0                    0
# 35               42,159              230,760              581,434
# 36                    0                    0                    0
# 37                    0                    0                    0
# 38              602,545              810,091            1,049,458
# 39                    0                    0                    0
# 40               69,122               76,931               83,059
# 41              345,591              415,115              502,741
# 42                    0                    0                    0
# 43              105,602              261,727              422,813
# 44                    0                    0                    0
# 45                    0                    0                    0
# 46              154,465              217,713              235,764
# 47              807,557              877,683              938,261
# 48                    0                    0                    0
# 49               78,592              105,469              136,808
# 50                    0                    0                1,444
# 51                    0                    0                    0
# 52                    0                    0                    0
# 53                    0                    0                    0
# 54                    0                    0                    0
# 55                    0                    0                    0
# 56                    0                    0                    0
# 57                    0                    0                    0
# 58                    0                    0                    0
#
#    1830_TotalPopulation 1840_TotalPopulation 1850_TotalPopulation  ...  \
# 0               309,527              590,756              771,623  ...
# 1                     0                    0                    0  ...
# 2                     0                    0                    0  ...
# 3                30,388               97,574              209,897  ...
# 4                     0                    0               92,597  ...
# 5                     0                    0                    0  ...
# 6               297,675              309,978              370,792  ...
# 7                76,748               78,085               91,532  ...
# 8                30,261               33,745               51,687  ...
# 9                34,730               54,477               87,445  ...
# 10              516,823              691,392              906,185  ...
# 11                    0                    0                    0  ...
# 12                    0                    0                    0  ...
# 13              157,445              476,183              851,470  ...
# 14              343,031              685,866              988,416  ...
# 15                    0               43,112              192,214  ...
# 16                    0                    0                    0  ...
# 17              687,917              779,828              982,405  ...
# 18              215,739              352,411              517,762  ...
# 19              399,455              501,793              583,169  ...
# 20              447,040              470,019              583,034  ...
# 21              610,408              737,699              994,514  ...
# 22               28,004              212,267              397,654  ...
# 23                    0                    0                6,077  ...
# 24              136,621              375,651              606,526  ...
# 25              140,455              383,702              682,044  ...
# 26                    0                    0                    0  ...
# 27                    0                    0                    0  ...
# 28                    0                    0                    0  ...
# 29              269,328              284,574              317,976  ...
# 30              320,823              373,306              489,555  ...
# 31                    0                    0               61,547  ...
# 32            1,918,608            2,428,921            3,097,394  ...
# 33              737,987              753,419              869,039  ...
# 34                    0                    0                    0  ...
# 35              937,903            1,519,467            1,980,329  ...
# 36                    0                    0                    0  ...
# 37                    0                    0               12,093  ...
# 38            1,348,233            1,724,033            2,311,786  ...
# 39                    0                    0                    0  ...
# 40               97,199              108,830              147,545  ...
# 41              581,185              594,398              668,507  ...
# 42                    0                    0                    0  ...
# 43              681,904              829,210            1,002,717  ...
# 44                    0                    0              212,592  ...
# 45                    0                    0               11,380  ...
# 46              280,652              291,948              314,120  ...
# 47            1,044,054            1,025,227            1,119,348  ...
# 48                    0                    0                1,201  ...
# 49              176,924              224,537              302,313  ...
# 50                3,635               30,945              305,391  ...
# 51                    0                    0                    0  ...
# 52                    0                    0                    0  ...
# 53                    0                    0                    0  ...
# 54                    0                    0                    0  ...
# 55                    0                    0                    0  ...
# 56                    0                    0                    0  ...
# 57                    0                    0                    0  ...
# 58                    0                    0                    0  ...
#
#    1950_TotalPopulation 1960_TotalPopulation 1970_TotalPopulation  \
# 0             3,061,743            3,266,740            3,444,165
# 1               128,643              226,167              300,382
# 2               749,587            1,302,161            1,770,900
# 3             1,909,511            1,786,272            1,923,295
# 4            10,586,223           15,717,204           19,953,134
# 5             1,325,089            1,753,947            2,207,259
# 6             2,007,280            2,535,234            3,031,709
# 7               318,085              446,292              548,104
# 8               802,178              763,956              756,510
# 9             2,771,305            4,951,560            6,789,443
# 10            3,444,578            3,943,116            4,589,575
# 11              499,794              632,772              768,561
# 12              588,637              667,191              712,567
# 13            8,712,176           10,081,158           11,113,976
# 14            3,934,224            4,662,498            5,193,669
# 15            2,621,073            2,757,537            2,824,376
# 16            1,905,299            2,178,611            2,246,578
# 17            2,944,806            3,038,156            3,218,706
# 18            2,683,516            3,257,022            3,641,306
# 19              913,774              969,265              992,048
# 20            2,343,001            3,100,689            3,922,399
# 21            4,690,514            5,148,578            5,689,170
# 22            6,371,766            7,823,194            8,875,083
# 23            2,982,483            3,413,864            3,804,971
# 24            2,178,914            2,178,141            2,216,912
# 25            3,954,653            4,319,813            4,676,501
# 26              591,024              674,767              694,409
# 27            1,325,510            1,411,330            1,483,493
# 28              160,083              285,278              488,738
# 29              533,242              606,921              737,681
# 30            4,835,329            6,066,782            7,168,164
# 31              681,187              951,023            1,016,000
# 32           14,830,192           16,782,304           18,236,967
# 33            4,061,929            4,556,155            5,082,059
# 34              619,636              632,446              617,761
# 35            7,946,627            9,706,397           10,652,017
# 36            2,233,351            2,328,284            2,559,229
# 37            1,521,341            1,768,687            2,091,385
# 38           10,498,012           11,319,366           11,793,909
# 39            2,210,703            2,349,544            2,712,033
# 40              791,896              859,488              946,725
# 41            2,117,027            2,382,594            2,590,516
# 42              652,740              680,514              665,507
# 43            3,291,718            3,567,089            3,923,687
# 44            7,711,194            9,579,677           11,196,730
# 45              688,862              890,627            1,059,273
# 46              377,747              389,881              444,330
# 47            3,318,680            3,966,949            4,648,494
# 48            2,378,963            2,853,214            3,409,169
# 49            2,005,552            1,860,421            1,744,237
